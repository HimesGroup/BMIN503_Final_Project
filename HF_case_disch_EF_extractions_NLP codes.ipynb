# %%
#import standard python packages for processing texts
import os, sys, re, glob
import pandas as pd

#import custom scripts for processing LVEF from texts from 
#Wagholikar KB, Fischer CM, Goodson A, Herrick CD, Rees M, 
#Toscano E, MacRae CA, Scirica BM, Desai AS, Murphy SN. 
#Extraction of Ejection Fraction from Echocardiography Notes for 
#Constructing a Cohort of Patients having Heart Failure 
#with reduced Ejection Fraction (HFrEF). 
#J Med Syst. 2018 Sep 25;42(11):209. 
#doi: 10.1007/s10916-018-1066-7. PMID: 30255347; PMCID: PMC6153777.

#https://github.com/waghsk/lvef-paper

from lvef_paper_master.echoNonTabularEF import echoNonTabularEF 
from lvef_paper_master.getSectionHeaders import isLineAHeader, getParas, getEFParaHeads
from lvef_paper_master.isReducedEF import efDataType, isReducedEF

# %%
#get txts from directory
txts=glob.glob(os.getcwd()+"/HF_case_disch/*.txt")
txts
# Out:
# ['/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/51157_119216_4252_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/21280_118318_5327_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/22289_117597_2421_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/24588_176009_3150_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/16278_116342_2246_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/11043_171810_1714_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/30543_105372_369_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/30213_133682_334_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/55973_159695_4028_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/99469_189343_8417_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/21312_150854_4086_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/25574_105670_5170_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/27914_144022_4527_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/11590_116582_2409_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/4685_184648_3352_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/27879_107921_4241_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/25820_162299_5041_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/22780_138174_5572_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/28426_153325_1453_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/7973_144659_944_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/11862_144919_3680_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/55973_145185_4034_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/3952_197882_5122_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/11624_100775_2426_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/11142_197704_5036_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/26368_194903_5261_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/4292_176904_1440_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/99485_198458_1705_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/14269_134590_1826_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/9545_189678_2492_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/65190_146245_1964_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/7973_122900_945_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/16873_138089_11540_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/9801_146305_166_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/98890_147030_2167_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/2272_192808_5032_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/3593_169494_4187_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/22330_136390_4617_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/11043_165605_1717_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/29509_161268_3911_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/26936_144288_888_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/76797_164212_3904_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/2378_173442_1639_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/71184_168624_521_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/58242_189391_508_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/55973_152234_4029_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/99439_143661_2102_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/6069_130702_4575_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/15594_116266_3732_Discharge summary_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_disch/4979_114218_5103_Discharge summary_HF_.txt']

# %%
#get headers from csv
headerArr=pd.read_csv(os.getcwd()+"/lvef_paper_master/headers.csv", header=0)
headerArr
# Out:
#                  Result Report
# 0                 Patient Name:
# 1                Ordering Prov:
# 2       Primary Care Physician:
# 3              Reason For Exam:
# 4                Result Status:
# ..                          ...
# 63          Left Atrium - Post
# 64       Pulmonic Valve - Post
# 65   Interatrial Septum - Post
# 66          Pericardium - Post
# 67               Next Follow-Up
#
# [68 rows x 1 columns]

# %%
#extract the EFs from texts

with open(os.getcwd()+"/HF_case_disch_EF_extractions_NLP.txt", "w") as file_out:
    
    file_out.write(f"File name\tLVEF string\tLVEF_value\tPat note\n")
    
    for txt_file in txts:
        with open(txt_file, "r") as txt:

            path, name = os.path.split(txt_file)

            txt=txt.read()
            LVEF_str, LVEF_value, pat_type = echoNonTabularEF(txt)
            txt=txt.replace("\n", " ")
            txt=txt.replace("\t", " ")
            
            file_out.write(f"{name}\t{LVEF_str}\t{LVEF_value}\t{txt}\n")
