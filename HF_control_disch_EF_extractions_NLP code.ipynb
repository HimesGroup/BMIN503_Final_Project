# %%
#import standard python packages for processing texts
import os, sys, re, glob
import pandas as pd

#import custom scripts for processing LVEF from texts from 
#Wagholikar KB, Fischer CM, Goodson A, Herrick CD, Rees M, 
#Toscano E, MacRae CA, Scirica BM, Desai AS, Murphy SN. 
#Extraction of Ejection Fraction from Echocardiography Notes for 
#Constructing a Cohort of Patients having Heart Failure 
#with reduced Ejection Fraction (HFrEF). 
#J Med Syst. 2018 Sep 25;42(11):209. 
#doi: 10.1007/s10916-018-1066-7. PMID: 30255347; PMCID: PMC6153777.

#https://github.com/waghsk/lvef-paper

from lvef_paper_master.echoNonTabularEF import echoNonTabularEF 
from lvef_paper_master.getSectionHeaders import isLineAHeader, getParas, getEFParaHeads
from lvef_paper_master.isReducedEF import efDataType, isReducedEF

# %%
#get txts from directory
txts=glob.glob(os.getcwd()+"/HF_control_disch/*.txt")
txts
# Out:
# ['/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_control_disch/13702_196489_177_Discharge summary_noHF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_control_disch/13702_107527_175_Discharge summary_noHF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_control_disch/22532_167853_174_Discharge summary_noHF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_control_disch/20646_134727_180_Discharge summary_noHF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_control_disch/26880_135453_178_Discharge summary_noHF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_control_disch/53181_170490_179_Discharge summary_noHF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_control_disch/13702_167118_176_Discharge summary_noHF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_control_disch/42130_114236_181_Discharge summary_noHF_.txt']

# %%
#get headers from csv
headerArr=pd.read_csv(os.getcwd()+"/lvef_paper_master/headers.csv", header=0)
headerArr
# Out:
#                  Result Report
# 0                 Patient Name:
# 1                Ordering Prov:
# 2       Primary Care Physician:
# 3              Reason For Exam:
# 4                Result Status:
# ..                          ...
# 63          Left Atrium - Post
# 64       Pulmonic Valve - Post
# 65   Interatrial Septum - Post
# 66          Pericardium - Post
# 67               Next Follow-Up
#
# [68 rows x 1 columns]

# %%
#extract the EFs from texts

with open(os.getcwd()+"/HF_control_disch_EF_extractions_NLP.txt", "w") as file_out:
    
    file_out.write(f"File name\tLVEF string\tLVEF_value\tPat note\n")
    
    for txt_file in txts:
        with open(txt_file, "r") as txt:

            path, name = os.path.split(txt_file)

            txt=txt.read()
            LVEF_str, LVEF_value, pat_type = echoNonTabularEF(txt)
            txt=txt.replace("\n", " ")
            txt=txt.replace("\t", " ")
            
            file_out.write(f"{name}\t{LVEF_str}\t{LVEF_value}\t{txt}\n")
