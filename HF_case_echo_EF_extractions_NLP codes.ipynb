# %%
#import standard python packages for processing texts
import os, sys, re, glob
import pandas as pd

#import custom scripts for processing LVEF from texts from 
#Wagholikar KB, Fischer CM, Goodson A, Herrick CD, Rees M, 
#Toscano E, MacRae CA, Scirica BM, Desai AS, Murphy SN. 
#Extraction of Ejection Fraction from Echocardiography Notes for 
#Constructing a Cohort of Patients having Heart Failure 
#with reduced Ejection Fraction (HFrEF). 
#J Med Syst. 2018 Sep 25;42(11):209. 
#doi: 10.1007/s10916-018-1066-7. PMID: 30255347; PMCID: PMC6153777.

#https://github.com/waghsk/lvef-paper

from lvef_paper_master.echoNonTabularEF import echoNonTabularEF 
from lvef_paper_master.getSectionHeaders import isLineAHeader, getParas, getEFParaHeads
from lvef_paper_master.isReducedEF import efDataType, isReducedEF

# %%
#get txts from directory
txts=glob.glob(os.getcwd()+"/HF_case_echo/*.txt")
txts
# Out:
# ['/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/4685_184648_62308_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/26368_194903_63228_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/22330_136390_65377_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/15594_116266_63306_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/76797_164212_63786_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/26936_144288_60721_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/22659_159352_64505_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/28426_153325_61698_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/49274_120922_64699_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/58242_189391_60096_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/9801_146305_59794_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/30213_133682_59980_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/25820_162299_65259_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/23697_129988_65601_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/71184_168624_60060_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/21312_150854_64207_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/12733_163392_65536_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/29509_161268_63241_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/55973_159695_63955_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/21312_150854_64206_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/22330_136390_65419_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/22289_117597_62824_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/28426_153325_61697_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/15147_197424_64708_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/4685_184648_62452_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/12733_158238_65535_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/3952_197882_63405_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/11624_100775_62851_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/22330_136390_65378_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/6069_130702_65011_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/4685_184648_62307_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/3952_197882_63426_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/15147_197424_64709_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/14269_134590_60963_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/4685_184648_62306_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/11624_100775_62850_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/27914_144022_64809_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/15594_116266_63417_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/27879_107921_63795_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/9545_189678_61256_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/76797_164212_63785_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/98890_147030_60813_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/99485_198458_61939_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/7973_122900_60434_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/11624_100775_62849_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/11862_144919_64062_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/22330_136390_65420_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/4685_184648_62458_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/2272_192808_63398_Echo_HF_.txt',
#  '/Users/godefroychery/Desktop/LVEF_NLP/LVEF_ECHO_implementation_with_python/HF_case_echo/16278_116342_61069_Echo_HF_.txt']

# %%
#get headers from csv
headerArr=pd.read_csv(os.getcwd()+"/lvef_paper_master/headers.csv", header=0)
headerArr
# Out:
#                  Result Report
# 0                 Patient Name:
# 1                Ordering Prov:
# 2       Primary Care Physician:
# 3              Reason For Exam:
# 4                Result Status:
# ..                          ...
# 63          Left Atrium - Post
# 64       Pulmonic Valve - Post
# 65   Interatrial Septum - Post
# 66          Pericardium - Post
# 67               Next Follow-Up
#
# [68 rows x 1 columns]

# %%
#extract the EFs from texts

with open(os.getcwd()+"/HF_case_echo_EF_extractions_NLP.txt", "w") as file_out:
    
    file_out.write(f"File name\tLVEF string\tLVEF_value\tPat note\n")
    
    for txt_file in txts:
        with open(txt_file, "r") as txt:

            path, name = os.path.split(txt_file)

            txt=txt.read()
            LVEF_str, LVEF_value, pat_type = echoNonTabularEF(txt)
            txt=txt.replace("\n", " ")
            txt=txt.replace("\t", " ")
            
            file_out.write(f"{name}\t{LVEF_str}\t{LVEF_value}\t{txt}\n")
